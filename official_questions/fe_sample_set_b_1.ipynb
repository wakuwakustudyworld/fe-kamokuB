# %% [markdown]
# ## 基本情報技術者試験（科目B試験）サンプル問題セット
# ### 問1
# 次の記述中の <span style="border: solid 1px">　　　</span> に入れる正しい答えを，解答群の中から選べ。
#
# プログラムを実行すると，“<span style="border: solid 1px">　　　</span>”と出力される。
#
# ### 〔プログラム〕
# <pre>
# 　整数型:x ← 1
# 　整数型:y ← 2
# 　整数型:z ← 3
# 　x ← y
# 　y ← z
# 　z ← x
# 　yの値と zの値をこの順にコンマ区切りで出力する
# </pre>
#
# ### 解答群
# ア 1,2
# イ 1,3
# ウ 2,1
# エ 2,3
# オ 3,1
# カ 3,2

# %%
x : int = 1
y : int = 2
z : int = 3
x = y
y = z
z = x
print(y, ',', z)
# Out:
# 3 , 2
